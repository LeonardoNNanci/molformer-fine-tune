# %% [markdown]
# ## Load Model

# %% [markdown]
# ## Inference

# %%
from common import *
import pandas as pd

lm, tokenizer = load_model()
# Out:
# Global seed set to 12345
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Global seed set to 12345
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding

# %%
data = pd.read_csv("../../data/ld50/train.csv")
data
# Out:
#       Unnamed: 0  BCUTi-1h  BCUTd-1h  TopoPSA(NO)  BCUTs-1l     VR3_D  \
# 0          10324  0.575003  0.939557     0.046798  0.257801  0.614440
# 1            865  0.602402  0.728098     0.011069  0.354324  0.435993
# 2           9113  0.182587  0.776507     0.000000  0.225516  0.483295
# 3           2985  0.442271  0.728085     0.010412  0.289029  0.399393
# 4           4065  0.574230  0.937718     0.012946  0.251752  0.457640
# ...          ...       ...       ...          ...       ...       ...
# 7992        4016  0.574692  0.937937     0.026493  0.256539  0.490391
# 7993        2129  0.595962  0.936983     0.024668  0.253587  0.523148
# 7994        6518  0.573246  0.707073     0.025068  0.287026  0.313928
# 7995       11385  0.140814  0.712108     0.000000  0.352947  0.320470
# 7996        4899  0.573664  0.939165     0.021821  0.258262  0.493993
#
#       SMR_VSA1  BCUTv-1h  SlogP_VSA2  BCUTd-1l  ...     MID_h   MDEC-23  \
# ...

# %%
smiles = data["smiles"].apply(canonicalize)
smiles
# Out:
# 0       CC(C)C1(NC(=O)C2C=C3c4cccc5[nH]cc(c45)CC3N(C)C...
# 1                              CN(C)c1ccc(N=Nc2ccccc2)cc1
# 2       Brc1c(Br)c(Br)c(-c2c(Br)c(Br)c(Br)c(Br)c2Br)c(...
# 3                                 CC(=O)OCc1ccc(C(C)C)cc1
# 4                           COc1cccc(C2(O)CCCCC2CN(C)C)c1
#                               ...
# 7992         C#CCN1CC(=O)N(COC(=O)C2C(C=C(C)C)C2(C)C)C1=O
# 7993            CCCCC1(CC)COC(Cn2cncn2)(c2cc3ccccc3o2)OC1
# 7994                                      C=CC(N)CCC(=O)O
# 7995                                       C=Cc1ccc(C)cc1
# 7996                CC(C)NCCCC1(C(N)=O)c2ccccc2-c2ccccc21
# Name: smiles, Length: 7997, dtype: object

# %%
smiles = data.smiles.apply(canonicalize)
X = embed(lm, smiles, tokenizer)

# %%
embeddings = pd.DataFrame(X)
embeddings.to_csv("train_embeddings.csv", index=False)
